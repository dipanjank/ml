# %% [markdown]
# This is an example of how to use Tensorflow Data Validation (https://www.tensorflow.org/tfx/data_validation/get_started) to detect changes in tabular datasets.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_data_validation as tfdv


print(tf.__version__)
print(tfdv.__version__)
# Out:
# 2.9.1
# 1.8.0

# %% [markdown]
# First we read a tabular dataset with numerical data. This is taken from the UCI Machine Learning Dataset Archive: https://archive.ics.uci.edu/ml/datasets/banknote+authentication. This dataset contains features calculated from pixel values of images of authentic and fake banknotes.

# %%
data_df = pd.read_csv(
    "data_banknote_authentication.txt",
    names=["variance", "skewness", "kurtosis", "entropy", "class"]
)
data_df.head()
# Out:
#    variance  skewness  kurtosis  entropy  class
# 0   3.62160    8.6661   -2.8073 -0.44699      0
# 1   4.54590    8.1674   -2.4586 -1.46210      0
# 2   3.86600   -2.6383    1.9242  0.10645      0
# 3   3.45660    9.5228   -4.0112 -3.59440      0
# 4   0.32924   -4.4552    4.5718 -0.98880      0

# %% [markdown]
# We split the dataset into a "baseline" and an "update". We use the baseline to generate a schema which contains details of the columns, their data types and other expectations.

# %%
baseline_df = data_df.sample(1000, random_state=12345)
update_df = data_df.loc[data_df.index.difference(baseline_df.index), ]

print(baseline_df.shape)
print(update_df.shape)
# Out:
# (1000, 5)
# (372, 5)

# %%
baseline_stats = tfdv.generate_statistics_from_dataframe(baseline_df)
baseline_stats
# Out:
# datasets {
#   num_examples: 1000
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 1000
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 1000
#       }
#       mean: 0.4203264224
#       std_dev: 2.922803233723026
#       min: -7.0421
#       median: 0.47368
#       max: 6.8248
#       histograms {
#         buckets {
#           low_value: -7.0421
#           high_value: -5.65541
#           sample_count: 16.930893393393394
#         }
#         buckets {
#           low_value: -5.65541
#           high_value: -4.26872
#           sample_count: 30.47913047295505
#         }
#         buckets {
#           low_value: -4.26872
#           high_value: -2.8820299999999994
#           sample_count: 91.6098391473502
#         }
#         buckets {
#           low_value: -2.8820299999999994
#           high_value: -1.4953399999999997
#           sample_count: 158.6529846684206
#         }
#         buckets {
#           low_value: -1.4953399999999997
#           high_value: -0.10864999999999991
#           sample_count: 140.91979273105056
#         }
#         buckets {
#           low_value: -0.10864999999999991
#           high_value: 1.2780400000000007
#           sample_count: 150.88526656357442
#         }
#         buckets {
#           low_value: 1.2780400000000007
#           high_value: 2.6647300000000005
#           sample_count: 138.06551407588742
#         }
#         buckets {
#           low_value: 2.6647300000000005
#           high_value: 4.05142
#           sample_count: 154.37820056899008
#         }
#         buckets {
#           low_value: 4.05142
#           high_value: 5.43811
#           sample_count: 103.08032873298822
#         }
#         buckets {
#           low_value: 5.43811
#           high_value: 6.8248
#           sample_count: 14.998049645390067
#         }
#       }
#       histograms {
#         buckets {
#           low_value: -7.0421
#           high_value: -3.3924
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -3.3924
#           high_value: -2.2677
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -2.2677
#           high_value: -1.4781
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -1.4781
#           high_value: -0.49241
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -0.49241
#           high_value: 0.47368
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 0.47368
#           high_value: 1.3451
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 1.3451
#           high_value: 2.3952
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 2.3952
#           high_value: 3.4893
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 3.4893
#           high_value: 4.1757
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 4.1757
#           high_value: 6.8248
#           sample_count: 100.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "variance"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 1000
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 1000
#       }
#       mean: 1.794496547
#       std_dev: 5.981864487524273
#       min: -13.7731
#       median: 2.3383
#       max: 12.9516
#       histograms {
#         buckets {
#           low_value: -13.7731
#           high_value: -11.100629999999999
#           sample_count: 25.79808259587021
#         }
#         buckets {
#           low_value: -11.100629999999999
#           high_value: -8.42816
#           sample_count: 28.387222063627988
#         }
#         buckets {
#           low_value: -8.42816
#           high_value: -5.755690000000001
#           sample_count: 72.47512005092649
#         }
#         buckets {
#           low_value: -5.755690000000001
#           high_value: -3.0832200000000007
#           sample_count: 101.00667206376883
#         }
#         buckets {
#           low_value: -3.0832200000000007
#           high_value: -0.41075000000000017
#           sample_count: 74.92230605632079
#         }
#         buckets {
#           low_value: -0.41075000000000017
#           high_value: 2.261719999999997
#           sample_count: 194.3332737494112
#         }
#         buckets {
#           low_value: 2.261719999999997
#           high_value: 4.934189999999997
#           sample_count: 183.38268535036931
#         }
#         buckets {
#           low_value: 4.934189999999997
#           high_value: 7.606659999999998
#           sample_count: 117.67559045065656
#         }
#         buckets {
#           low_value: 7.606659999999998
#           high_value: 10.279129999999999
#           sample_count: 142.47590245775822
#         }
#         buckets {
#           low_value: 10.279129999999999
#           high_value: 12.9516
#           sample_count: 59.54314516129037
#         }
#       }
#       histograms {
#         buckets {
#           low_value: -13.7731
#           high_value: -6.6072
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -6.6072
#           high_value: -3.7971
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -3.7971
#           high_value: -0.48422
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -0.48422
#           high_value: 0.70975
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 0.70975
#           high_value: 2.3383
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 2.3383
#           high_value: 3.3812
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 3.3812
#           high_value: 5.6264
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 5.6264
#           high_value: 7.6336
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 7.6336
#           high_value: 9.5083
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 9.5083
#           high_value: 12.9516
#           sample_count: 100.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "skewness"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 1000
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 1000
#       }
#       mean: 1.4392359458900001
#       std_dev: 4.438841155693295
#       min: -5.2861
#       median: 0.61663
#       max: 17.9274
#       histograms {
#         buckets {
#           low_value: -5.2861
#           high_value: -2.9647500000000004
#           sample_count: 146.80243902439022
#         }
#         buckets {
#           low_value: -2.9647500000000004
#           high_value: -0.6434000000000006
#           sample_count: 186.00222569864175
#         }
#         buckets {
#           low_value: -0.6434000000000006
#           high_value: 1.6779499999999992
#           sample_count: 281.4370019436345
#         }
#         buckets {
#           low_value: 1.6779499999999992
#           high_value: 3.999299999999999
#           sample_count: 167.92500000000013
#         }
#         buckets {
#           low_value: 3.999299999999999
#           high_value: 6.320649999999998
#           sample_count: 78.58916738692021
#         }
#         buckets {
#           low_value: 6.320649999999998
#           high_value: 8.642
#           sample_count: 54.98782076874816
#         }
#         buckets {
#           low_value: 8.642
#           high_value: 10.963349999999998
#           sample_count: 46.06801184433163
#         }
#         buckets {
#           low_value: 10.963349999999998
#           high_value: 13.284699999999997
#           sample_count: 18.733127522195353
#         }
#         buckets {
#           low_value: 13.284699999999997
#           high_value: 15.606049999999996
#           sample_count: 5.949627717831691
#         }
#         buckets {
#           low_value: 15.606049999999996
#           high_value: 17.9274
#           sample_count: 13.50557809330633
#         }
#       }
#       histograms {
#         buckets {
#           low_value: -5.2861
#           high_value: -3.4414
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -3.4414
#           high_value: -2.3163
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -2.3163
#           high_value: -1.0671
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -1.0671
#           high_value: -0.1828
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -0.1828
#           high_value: 0.61663
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 0.61663
#           high_value: 1.4563
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 1.4563
#           high_value: 2.4957
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 2.4957
#           high_value: 4.5718
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 4.5718
#           high_value: 8.15
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 8.15
#           high_value: 17.9274
#           sample_count: 100.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "kurtosis"
#     }
#   }
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 1000
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 1000
#       }
#       mean: -1.2020481475000002
#       std_dev: 2.074403253454828
#       min: -8.5482
#       median: -0.59958
#       max: 2.4495
#       histograms {
#         buckets {
#           low_value: -8.5482
#           high_value: -7.44843
#           sample_count: 11.121105970478078
#         }
#         buckets {
#           low_value: -7.44843
#           high_value: -6.34866
#           sample_count: 17.059085167662666
#         }
#         buckets {
#           low_value: -6.34866
#           high_value: -5.248889999999999
#           sample_count: 24.439313505822128
#         }
#         buckets {
#           low_value: -5.248889999999999
#           high_value: -4.14912
#           sample_count: 50.027983940512
#         }
#         buckets {
#           low_value: -4.14912
#           high_value: -3.0493500000000004
#           sample_count: 92.79945019103529
#         }
#         buckets {
#           low_value: -3.0493500000000004
#           high_value: -1.94958
#           sample_count: 93.85782312925173
#         }
#         buckets {
#           low_value: -1.94958
#           high_value: -0.8498099999999997
#           sample_count: 162.83318394826776
#         }
#         buckets {
#           low_value: -0.8498099999999997
#           high_value: 0.24995999999999974
#           sample_count: 268.77700260057856
#         }
#         buckets {
#           low_value: 0.24995999999999974
#           high_value: 1.3497299999999992
#           sample_count: 237.79358813175762
#         }
#         buckets {
#           low_value: 1.3497299999999992
#           high_value: 2.4495
#           sample_count: 41.29146341463418
#         }
#       }
#       histograms {
#         buckets {
#           low_value: -8.5482
#           high_value: -4.1814
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -4.1814
#           high_value: -2.9957
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -2.9957
#           high_value: -1.8461
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -1.8461
#           high_value: -1.0974
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -1.0974
#           high_value: -0.59958
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -0.59958
#           high_value: -0.26079
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: -0.26079
#           high_value: 0.15429
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 0.15429
#           high_value: 0.50084
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 0.50084
#           high_value: 0.95343
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 0.95343
#           high_value: 2.4495
#           sample_count: 100.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "entropy"
#     }
#   }
#   features {
#     num_stats {
#       common_stats {
#         num_non_missing: 1000
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 100.0
#           }
#           type: QUANTILES
#         }
#         tot_num_values: 1000
#       }
#       mean: 0.455
#       std_dev: 0.49797088268291345
#       num_zeros: 545
#       max: 1.0
#       histograms {
#         buckets {
#           high_value: 0.1
#           sample_count: 544.1
#         }
#         buckets {
#           low_value: 0.1
#           high_value: 0.2
#           sample_count: 0.1
#         }
#         buckets {
#           low_value: 0.2
#           high_value: 0.30000000000000004
#           sample_count: 0.10000000000000003
#         }
#         buckets {
#           low_value: 0.30000000000000004
#           high_value: 0.4
#           sample_count: 0.09999999999999998
#         }
#         buckets {
#           low_value: 0.4
#           high_value: 0.5
#           sample_count: 0.09999999999999998
#         }
#         buckets {
#           low_value: 0.5
#           high_value: 0.6000000000000001
#           sample_count: 0.10000000000000009
#         }
#         buckets {
#           low_value: 0.6000000000000001
#           high_value: 0.7000000000000001
#           sample_count: 0.09999999999999998
#         }
#         buckets {
#           low_value: 0.7000000000000001
#           high_value: 0.8
#           sample_count: 0.09999999999999998
#         }
#         buckets {
#           low_value: 0.8
#           high_value: 0.9
#           sample_count: 0.09999999999999998
#         }
#         buckets {
#           low_value: 0.9
#           high_value: 1.0
#           sample_count: 455.1
#         }
#       }
#       histograms {
#         buckets {
#           sample_count: 100.0
#         }
#         buckets {
#           sample_count: 100.0
#         }
#         buckets {
#           sample_count: 100.0
#         }
#         buckets {
#           sample_count: 100.0
#         }
#         buckets {
#           sample_count: 100.0
#         }
#         buckets {
#           high_value: 1.0
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 100.0
#         }
#         buckets {
#           low_value: 1.0
#           high_value: 1.0
#           sample_count: 100.0
#         }
#         type: QUANTILES
#       }
#     }
#     path {
#       step: "class"
#     }
#   }
# }

# %%
schema = tfdv.infer_schema(statistics=baseline_stats)
tfdv.display_schema(schema)
# Out:
#                Type  Presence Valency Domain
# Feature name
# 'variance'    FLOAT  required              -
# 'skewness'    FLOAT  required              -
# 'kurtosis'    FLOAT  required              -
# 'entropy'     FLOAT  required              -
# 'class'         INT  required              -

# %% [markdown]
# Now we will validate the "update" part of the dataset against the schema we generated from the baseline.

# %%
def validate_update(schema, update_df):
    update_stats = tfdv.generate_statistics_from_dataframe(update_df)
    validation_result = tfdv.validate_statistics(
        statistics=update_stats,
        schema=schema,
    )
    return validation_result

# %%
# Update with no anomalies
no_anomaly = validate_update(schema=schema, update_df=update_df)
tfdv.display_anomalies(no_anomaly)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
# Update with the "variance" column missing
missing_variance = validate_update(
    schema=schema, 
    update_df=update_df.drop(["variance",], axis=1)
)
tfdv.display_anomalies(missing_variance)
# Out:
#              Anomaly short description      Anomaly long description
# Feature name
# 'variance'              Column dropped  Column is completely missing
